# %%
import pandas
import numpy as np

# %%
data=pandas.read_csv("p1.csv")
data.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
data['Stage_fear']=data['Stage_fear'].map({'No':0,'Yes':1})
data['Drained_after_socializing']=data['Drained_after_socializing'].map({"No":0,'Yes':1})

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
da=lb.fit_transform(data['Personality'])
data['pre']=da

# %%
data.head(3)
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         0.0                      4.0            6.0
# 1               9.0         1.0                      0.0            0.0
# 2               9.0         1.0                      1.0            2.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency Personality  \
# 0                        0.0                 13.0             5.0   Extrovert
# 1                        1.0                  0.0             3.0   Introvert
# 2                        1.0                  5.0             2.0   Introvert
#
#    pre
# 0    0
# 1    1
# 2    1

# %%
data.drop(columns=['Personality'],inplace=True)

# %%
data.head(4)
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         0.0                      4.0            6.0
# 1               9.0         1.0                      0.0            0.0
# 2               9.0         1.0                      1.0            2.0
# 3               0.0         0.0                      6.0            7.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  pre
# 0                        0.0                 13.0             5.0    0
# 1                        1.0                  0.0             3.0    1
# 2                        1.0                  5.0             2.0    1
# 3                        0.0                 14.0             8.0    0

# %%
x=data.drop(columns=['pre'])
y=data['pre']

# %%
x
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         0.0                      4.0            6.0
# 1                  9.0         1.0                      0.0            0.0
# 2                  9.0         1.0                      1.0            2.0
# 3                  0.0         0.0                      6.0            7.0
# 4                  3.0         0.0                      9.0            4.0
# ...                ...         ...                      ...            ...
# 2895               3.0         0.0                      7.0            6.0
# 2896               3.0         0.0                      8.0            3.0
# 2897               4.0         1.0                      1.0            1.0
# 2898              11.0         1.0                      1.0            NaN
# 2899               3.0         0.0                      6.0            6.0
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

log=LogisticRegression()
svc=SVC()
des=DecisionTreeClassifier()
ada=AdaBoostClassifier()
NAV=GaussianNB()

# %%
clfs={
    'LogisticRegression':log,
    'SVC':svc,
    'DecisionTreeClassifier':des,
    'AdaBoostClassifier':ada,
    'Gaussian':NAV
}

# %%
def classfier_(model,x_train,y_train,x_test,y_tes):
    model.fit(x_train,y_train)
    traaing_accuary=model.score(x_train,y_train)*100
    y_pred=model.predict(x_test)
    testing_accary=model.score(y_pred,y_test)*100
    return traaing_accuary,testing_accary

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 8
#       5     return training_accuracy, testing_accuracy
#       7 for name, model in clfs.items():
# ----> 8     training, testing = classifier_(model, x_train, y_train, x_test, y_test)
#       9     print(name)
#      10     print("training accuracy: " + str(training) + " and testing accuracy: " + str(testing))
#
# Cell In[45], line 2, in classifier_(model, x_train, y_train, x_test, y_test)
#       1 def classifier_(model, x_train, y_train, x_test, y_test):
# ----> 2     model.fit(x_train, y_train)
#       3     training_accuracy = model.score(x_train, y_train) * 100
#       4     testing_accuracy = model.score(x_test, y_test) * 100
#
# ...
